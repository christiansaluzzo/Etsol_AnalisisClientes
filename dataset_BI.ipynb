# %% [markdown]
# # Generación de diveros Dataset para el análisis en Power BI
#
# ### Analizar
#
# - Cliente
# - Productos
# - Ticktes
# - Facturación
#
# ### Consideraciones
#
# - Nombres de tablas y columnas que sean letras y _
# - Números para representar `$` con `.` para el decimal. Ejm `$ 458.59`
# - Todo en mayúsculas
# - Reemplazar caracteres especiales
# - Comentarios de tickets ...."tal como están".

# %% [markdown]
# # Cliente
#
# - `PK`
# - `Cod_cliente`
# - `Cliente`
# - `Nro_de_licencia`
# - `Estado`
# - `Rubro`

# %% [markdown]
# # Productos
#
# - `PK`
# - `Cod_Producto`
# - `Nombre_Producto`
# - `Precio_Venta`
# - `Precio_Abono`
# - `Activo`
# - `Cantidad_de_licencia`
# - `Fecha_Venta`
# - `Fecha_Alta`
# - `Fecha_Implementacion`

# %% [markdown]
# # Tickets
#
# - `PK`
# - `Numero_Ticket`
# - `Cod_Cliente`
# - `Cod_Producto`
# - `Quien abre`
# - `Quien cierra`
# - `Asunto`

# %% [markdown]
# # Facturación
#
# - `PK`
# - `Cod_Cliente`
# - `Cod_Producto`
# - `Fecha`
# - `Abono`
